# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/501/sfsr_arda.zip
# Out:
# Archive:  /content/drive/MyDrive/501/sfsr_arda.zip
#    creating: Attention-Is-All-You-Need-In-Speech-Separation-main/
#   inflating: Attention-Is-All-You-Need-In-Speech-Separation-main/train.py
#   inflating: Attention-Is-All-You-Need-In-Speech-Separation-main/README.md
#    creating: Attention-Is-All-You-Need-In-Speech-Separation-main/min/
#    creating: Attention-Is-All-You-Need-In-Speech-Separation-main/min/tr/
#    creating: Attention-Is-All-You-Need-In-Speech-Separation-main/min/tr/mix/
#   inflating: Attention-Is-All-You-Need-In-Speech-Separation-main/min/tr/mix/14-212-0013_7926-254949-0054.wav
#   inflating: Attention-Is-All-You-Need-In-Speech-Separation-main/min/tr/mix/17-362-0014_2999-156967-0015.wav
#   inflating: Attention-Is-All-You-Need-In-Speech-Separation-main/min/tr/mix/17-362-0027_3835-178030-0019.wav
#   inflating: Attention-Is-All-You-Need-In-Speech-Separation-main/min/tr/mix/23-124439-0030_3340-169293-0042.wav
# ...

# %%
# !unzip /content/drive/MyDrive/501/Attention-Is-All-You-Need-In-Speech-Separation-main.zip
# Out:
# Archive:  /content/drive/MyDrive/501/Attention-Is-All-You-Need-In-Speech-Separation-main.zip
# replace Attention-Is-All-You-Need-In-Speech-Separation-main/train.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: yes All
#   inflating: Attention-Is-All-You-Need-In-Speech-Separation-main/train.py
# replace Attention-Is-All-You-Need-In-Speech-Separation-main/README.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Attention-Is-All-You-Need-In-Speech-Separation-main/README.md
# replace Attention-Is-All-You-Need-In-Speech-Separation-main/evaluate.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Attention-Is-All-You-Need-In-Speech-Separation-main/evaluate.py
# replace Attention-Is-All-You-Need-In-Speech-Separation-main/separate.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Attention-Is-All-You-Need-In-Speech-Separation-main/separate.py
# replace Attention-Is-All-You-Need-In-Speech-Separation-main/json/tr/mix.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# ...

# %%
# !python /content/Attention-Is-All-You-Need-In-Speech-Separation-main/dataset/preprocess.py

# %%
# !pip install json5
# !pip install adamp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for json5: filename=json5-0.9.8-py2.py3-none-any.whl size=18604 sha256=1e12b1234f1492b03222f3bafcc967955b8ffc8e9fd0f23cec41821bf46161b1
#   Stored in directory: /root/.cache/pip/wheels/ac/9b/de/6e4fd8f159d3dfa42c42ceddf2184fda29ea7fb1e8f5f8371c
# Successfully built json5
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5998 sha256=99308fdcdcbcc1dc588e89690d82d683d8d91a4caa60fdfb92402a0f78e5ab4d
#   Stored in directory: /root/.cache/pip/wheels/bb/95/21/ced2d2cb9944e3a72e58fece7958973eed3fd8d0aeb6e2e450
# Successfully built adamp
# ...

# %%
# !pip install torchinfo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %run /content/Attention-Is-All-You-Need-In-Speech-Separation-main/train.py
# Out:
# #### Encoder is initialized!!!
# ####Heuristic is initializedd!!
# Train Start...
# Epoch 1 | Iter 1 | Average Loss 34.545 | Current Loss 34.545208 | 2.5 s/batch
# Epoch 1 | Iter 2 | Average Loss 25.024 | Current Loss 15.502438 | 2.6 s/batch
# Epoch 1 | Iter 3 | Average Loss 19.136 | Current Loss 7.359169 | 2.5 s/batch
# Epoch 1 | Iter 4 | Average Loss 16.358 | Current Loss 8.026470 | 2.5 s/batch
# Epoch 1 | Iter 5 | Average Loss 14.406 | Current Loss 6.597928 | 2.5 s/batch
# Epoch 1 | Iter 6 | Average Loss 13.300 | Current Loss 7.767255 | 2.5 s/batch
# Epoch 1 | Iter 7 | Average Loss 12.140 | Current Loss 5.179559 | 2.5 s/batch
# Epoch 1 | Iter 8 | Average Loss 10.942 | Current Loss 2.558481 | 2.3 s/batch
# Epoch 1 | Iter 9 | Average Loss 9.824 | Current Loss 0.882465 | 2.3 s/batch
# Epoch 1 | Iter 10 | Average Loss 9.129 | Current Loss 2.871787 | 2.3 s/batch
# Epoch 1 | Iter 11 | Average Loss 8.697 | Current Loss 4.373893 | 2.3 s/batch
# ...

# %%
# !pip install mir_eval
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 90 kB 5.6 MB/s
# ...
#   Created wheel for mir-eval: filename=mir_eval-0.7-py3-none-any.whl size=100721 sha256=109e9c5ac70578444d1cb556fcf04a68e3faa09cc9e4303a5d9dbd10cb0cabd7
#   Stored in directory: /root/.cache/pip/wheels/18/5a/46/d2527ff1fd975e1a793375e6ed763bfe4d3ea396b7cdc470eb
# Successfully built mir-eval
# ...

# %%
# !python /content/Attention-Is-All-You-Need-In-Speech-Separation-main/evaluate.py
# Out:
# Utt 1 :
#     SDRi = 0.06,
#     SI-SNRi = -0.62
# Utt 2 :
#     SDRi = 6.02,
#     SI-SNRi = 5.19
# Utt 3 :
#     SDRi = 0.13,
#     SI-SNRi = -0.31
# Utt 4 :
#     SDRi = 3.99,
#     SI-SNRi = 3.60
# Utt 5 :
#     SDRi = 1.86,
#     SI-SNRi = 1.22
# Utt 6 :
#     SDRi = -0.11,
#     SI-SNRi = -0.57
# Utt 7 :
#     SDRi = 0.26,
#     SI-SNRi = -0.18
# Utt 8 :
#     SDRi = 4.98,
#     SI-SNRi = 4.70
# Utt 9 :
#     SDRi = -0.72,
#     SI-SNRi = -1.29
# Utt 10 :
#     SDRi = 5.35,
#     SI-SNRi = 4.53
# Utt 11 :
#     SDRi = 5.75,
#     SI-SNRi = 5.39
# Utt 12 :
#     SDRi = 1.84,
#     SI-SNRi = 1.43
# Utt 13 :
#     SDRi = 1.71,
#     SI-SNRi = 1.03
# Utt 14 :
#     SDRi = 4.58,
#     SI-SNRi = 3.85
# Utt 15 :
#     SDRi = -0.77,
#     SI-SNRi = -1.82
# Utt 16 :
#     SDRi = 0.33,
#     SI-SNRi = 0.06
# Utt 17 :
#     SDRi = -0.17,
#     SI-SNRi = -0.66
# Utt 18 :
#     SDRi = 2.27,
#     SI-SNRi = 1.94
# Utt 19 :
#     SDRi = 2.83,
#     SI-SNRi = 2.17
# Utt 20 :
# ...
